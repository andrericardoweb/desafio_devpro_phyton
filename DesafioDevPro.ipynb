# %% [markdown]
# # Desafio DevPro
# Nesse notebook vamos resolver vários exercícios da [lista da Phyton Brasil](https://wiki.python.org.br/ListaDeExercicios)

# %% [markdown]
# # [Estrutura Sequencial](https://wiki.python.org.br/EstruturaSequencial)

# %% [markdown]
# Exercício 1 - Faça um Programa que mostre a mensagem "Alo mundo" na tela.

# %%
print('Alo mundo')
# Out:
# Alo mundo

# %%
type('Olá Mundo')
# Out:
# str

# %% [markdown]
# Exercício 2 - Faça um Programa que peça um número e então mostre a mensagem O número informado foi [número].

# %%
numero = input('Digite um número: ')
print(f'O número informado foi {numero}')
# Out:
# Digite um número: 7
# O número informado foi 7

# %% [markdown]
# Exercício 3 - Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = eval(input('Digite um número: '))
numero2 = eval(input('Digite outro número: '))
soma = numero1 + numero2
print(f'{numero1} + {numero2} = {soma}')
# Out:
# Digite um número: 350
# Digite outro número: 200
# 350 + 200 = 550

# %% [markdown]
# Exercício 4 - Faça um Programa que peça as 4 notas bimestrais e mostre a média.

# %%
nota1 = eval(input('Nota 1: '))
nota2 = eval(input('Nota 2: '))
nota3 = eval(input('Nota 3: '))
nota4 = eval(input('Nota 4: '))
media = (nota1 + nota2 + nota3 + nota4) / 4
print(f'Média: {media:.2f}')
# Out:
# Nota 1: 5.5
# Nota 2: 8
# Nota 3: 4.25
# Nota 4: 9.9
# Média: 6.91

# %% [markdown]
# Exercício 5 - Faça um Programa que converta metros para centímetros.

# %%
valor_metros = eval(input('Digite o valor em metros: '))
print(f'{valor_metros} metros é igual a {valor_metros * 100} centímetros')
# Out:
# Digite o valor em metros: 50
# 50 metros é igual a 5000 centímetros

# %% [markdown]
# Exercício 6 - Faça um Programa que peça o raio de um círculo, calcule e mostre sua área.

# %%
raio_circulo = eval(input('Digite o raio do círculo em metros: '))
pi = 3.14
area_circulo = pi * raio_circulo**2
print(f'A área do círculo é de {area_circulo}m²')
# Out:
# Digite o raio do círculo em metros: 15
# A área do círculo é de 706.5m²

# %% [markdown]
# Exercício 7 - Faça um Programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

# %%
lado_quadrado = eval(input('Digite o tamanho de um lado do quadrado em metros:'))
area_quadrado = lado_quadrado**2
print(f'A área do quadrado são {area_quadrado}m² e o dobro são {area_quadrado * 2}m²')
# Out:
# Digite o tamanho de um lado do quadrado em metros:36
# A área do quadrado são 1296m² e o dobro são 2592m²

# %% [markdown]
# Exercício 8 - Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganho_por_hora = eval(input('Digite quanto você ganha por hora: R$'))
horas_trabalhadas_mes = eval(input('Digite quantas horas trabalhou no mês: '))
salario_mes = ganho_por_hora * horas_trabalhadas_mes
print(f'Total do salário no mês: R${salario_mes:.2f}')
# Out:
# Digite quanto você ganha por hora: R$20
# Digite quantas horas trabalhou no mês: 6
# Total do salário no mês: R$120.00

# %% [markdown]
# Exercício 9 - Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. C = 5 * ((F-32) / 9)

# %%
temperatura_f = eval(input('Digite a temperatura em graus Fahrenheit: '))
converte_f_para_c = 5 * ((temperatura_f - 32) / 9)
print(f'{temperatura_f} graus Fahrenheit é igual a {converte_f_para_c:.1f} graus Celsius')
# Out:
# Digite a temperatura em graus Fahrenheit: 32
# 32 graus Fahrenheit é igual a 0.0 graus Celsius

# %% [markdown]
# Exercício 10 - Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.

# %%
temperatura_celsius = eval(input('Digite a temperatura em graus Celsius: '))
converte_c_para_f = (temperatura_celsius * 1.8) + 32
print(f'{temperatura_celsius} graus Celsius é igual a {converte_c_para_f} graus Fahrenheit')
# Out:
# Digite a temperatura em graus Celsius: 0
# 0 graus Celsius é igual a 32.0 graus Fahrenheit

# %% [markdown]
# Exercício 11 - Faça um Programa que peça 2 números inteiros e um número real. Calcule e mostre:
# *   o produto do dobro do primeiro com metade do segundo .
# *   a soma do triplo do primeiro com o terceiro.
# *   o terceiro elevado ao cubo.

# %%
numero_1 = eval(input('Digite um número inteiro: '))
numero_2 = eval(input('Digite outro número inteiro: '))
numero_3 = eval(input('Digite um número real: '))
print(f'- O produto do dobro de {numero_1} com a metade de {numero_2} é igual a {(numero_1*2) * (numero_2/2)}')
print(f'- A soma do triplo de {numero_1} com {numero_3} é igual a {numero_1*3 + numero_3}')
print(f'- {numero_3} elevado ao cubo é igual a {numero_3**3:.2f}')
# Out:
# Digite um número inteiro: 5
# Digite outro número inteiro: 10
# Digite um número real: 5.5
# - O produto do dobro de 5 com a metade de 10 é igual a 50.0
# - A soma do triplo de 5 com 5.5 é igual a 20.5
# - 5.5 elevado ao cubo é igual a 166.38

# %% [markdown]
# Exercício 12 - Tendo como dados de entrada a altura de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
altura = eval(input('Qual sua altura em metros?  '))
peso_ideal = (72.7*altura) - 58
print(f'Peso ideal: {peso_ideal:.2f}Kg')
# Out:
# Qual sua altura em metros?  1.71
# Peso ideal: 66.32Kg

# %% [markdown]
# Exercício 13 - Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# *    Para homens: (72.7*h) - 58
# *    Para mulheres: (62.1*h) - 44.7

# %%
altura = eval(input('Qual sua altura em metros? '))
peso_ideal_homens = (72.7*altura) - 58
peso_ideal_mulheres = (62.1*altura) - 44.7
print(f'Peso ideal - Homens: {peso_ideal_homens:.2f}\nPeso ideal - Mulheres: {peso_ideal_mulheres:.2f}')
# Out:
# Qual sua altura em metros? 1.71
# Peso ideal - Homens: 66.32
# Peso ideal - Mulheres: 61.49

# %% [markdown]
# Exercício 14 - João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso_peixes = eval(input('Digite o peso dos peixes: '))
if peso_peixes  > 50:
  peso_excesso = peso_peixes - 50
  multa = 4 * peso_excesso
  print(f'Hoje João pescou {peso_peixes}Kg de peixes, {peso_excesso}Kg a mais que o estabelecido pelo regulamento e isso gerou uma multa de R${multa:.2f}')
else:
  print(f'Hoje João pescou {peso_peixes}Kg de peixes, está dentro do limite estabelecido pelo regulamento')
# Out:
# Digite o peso dos peixes: 99
# Hoje João pescou 99Kg de peixes, 49Kg a mais que o estabelecido pelo regulamento e isso gerou uma multa de R$196.00

# %% [markdown]
# Exercício 15 - Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
#
# *    salário bruto.
# *    quanto pagou ao IR.
# *    quanto pagou ao INSS.
# *    quanto pagou ao sindicato.
# *    o salário líquido.

# %%
ganho_hora = eval(input('Quanto você ganha por hora? R$ '))
horas_trabalhadas_mes = eval(input('Quantas horas trabalhou no mês? '))
salario_bruto  = ganho_hora * horas_trabalhadas_mes
imposto_renda = salario_bruto * 0.11
inss  = salario_bruto * 0.08
sindicato = salario_bruto * 0.05
descontos = imposto_renda + inss  + sindicato
salario_liquido = salario_bruto - descontos
print(f'+ Salário Bruto : R$ {salario_bruto:.2f}')
print(f'- IR (11%) : R$ {imposto_renda:.2f}')
print(f'- INSS (8%) : R$ {inss:.2f}')
print(f'- Sindicato ( 5%) : R$ {sindicato:.2f}')
print(f'= Salário Liquido : R$ {salario_liquido:.2f}')
# Out:
# Quanto você ganha por hora? R$ 20
# Quantas horas trabalhou no mês? 50
# + Salário Bruto : R$ 1000.00
# - IR (11%) : R$ 110.00
# - INSS (8%) : R$ 80.00
# - Sindicato ( 5%) : R$ 50.00
# = Salário Liquido : R$ 760.00

# %% [markdown]
# Exercício 16 - Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total.

# %%
area = eval(input('Área a ser pintada em m²: '))
litros_tinta = (area / 3)
quantidade_latas = round((litros_tinta / 18) + 0.5)
preco_total = quantidade_latas * 80
print(f'Para pintar uma área de {area}m² você precisará de {round(litros_tinta)} litros de tinta.\n\n- {quantidade_latas} latas de tinta.\n- Preço: R$ {preco_total:.2f}')
# Out:
# Área a ser pintada em m²: 300
# Para pintar uma área de 300m² você precisará de 100 litros de tinta.
#
# - 6 latas de tinta.
# - Preço: R$ 480.00

# %% [markdown]
# Exercício 17 - Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam  80,00 ou em galões de 3,6 litros, que custam R$ 25,00.
#
# *    Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações:
# *    comprar apenas latas de 18 litros;
# *    comprar apenas galões de 3,6 litros;
# *    misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %%
area = eval(input('Área a ser pintada em m²: '))
litros_tinta = (area / 6) * 1.10
qntd_latas = round((litros_tinta / 18) + 0.5)
qntd_galoes = round((litros_tinta / 3.6) + 0.5)
qntd_latas_mistura = round((litros_tinta / 18) - 0.5)
qntd_galoes_mistura = round(((litros_tinta - qntd_latas_mistura * 18) / 3.6 )  + 0.5) 
preco_lata = 80
preco_galao = 25
print(f'Para pintar uma área de {area}m² você precisará de {round(litros_tinta)} litros de tinta.')
print(f'\n- {qntd_latas} latas de tinta. Preço: R$ {(qntd_latas * preco_lata):.2f}')
print(f'ou\n- {qntd_galoes} galões de tinta. Preço: R$ {(qntd_galoes * preco_galao):.2f}')
print(f'ou\n- {qntd_latas_mistura} latas e {qntd_galoes_mistura} galões de tinta. Preço: R$ {((qntd_latas_mistura * preco_lata) + (qntd_galoes_mistura * preco_galao)):.2f}')
# Out:
# Área a ser pintada em m²: 300
# Para pintar uma área de 300m² você precisará de 55 litros de tinta.
#
# - 4 latas de tinta. Preço: R$ 320.00
# ou
# - 16 galões de tinta. Preço: R$ 400.00
# ou
# - 3 latas e 1 galões de tinta. Preço: R$ 265.00
